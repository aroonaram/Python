# %%
import pandas as pd
import numpy as np

# %%
filePath = 'D:/GitHub/Data Analysis/'

# %%
filename = filePath+'datasets.csv'

# %%
filename
# Out:
# 'D:/GitHub/Data Analysis/datasets.csv'

# %%
draft1 = pd.read_csv(filename)
draft1.head(2)
# Out:
#   Package          Item                              Title  Rows  Cols  \
# 0     AER       Affairs   Fair's Extramarital Affairs Data   601     9
# 1     AER  ArgentinaCPI  Consumer Price Index in Argentina    80     2
#
#    n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0         2            0         2          0          7
# 1         0            0         0          0          2
#
#                                                  CSV  \
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                  Doc
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...

# %%
pd.read_csv(filename, header = None).head(2)
# Out:
#         0        1                                 2     3     4         5   \
# 0  Package     Item                             Title  Rows  Cols  n_binary
# 1      AER  Affairs  Fair's Extramarital Affairs Data   601     9         2
#
#             6         7          8          9   \
# 0  n_character  n_factor  n_logical  n_numeric
# 1            0         2          0          7
#
#                                                   10  \
# 0                                                CSV
# 1  https://vincentarelbundock.github.io/Rdatasets...
#
#                                                   11
# 0                                                Doc
# 1  https://vincentarelbundock.github.io/Rdatasets...

# %%
pd.read_csv(filename, names = ['a','b','c','d','e','f','g','h','i','j','k']).head(2)
# Out:
#                a                                 b     c     d         e  \
# Package     Item                             Title  Rows  Cols  n_binary
# AER      Affairs  Fair's Extramarital Affairs Data   601     9         2
#
#                    f         g          h          i  \
# Package  n_character  n_factor  n_logical  n_numeric
# AER                0         2          0          7
#
#                                                          j  \
# Package                                                CSV
# AER      https://vincentarelbundock.github.io/Rdatasets...
#
#                                                          k
# Package                                                Doc
# AER      https://vincentarelbundock.github.io/Rdatasets...

# %%
pd.read_csv(filename, index_col= ['Package','Item']).head(4)
# Out:
#                                                                    Title  \
# Package Item
# AER     Affairs                         Fair's Extramarital Affairs Data
#         ArgentinaCPI                   Consumer Price Index in Argentina
#         BankWages                                             Bank Wages
#         BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
#
#                        Rows  Cols  n_binary  n_character  n_factor  n_logical  \
# Package Item
# AER     Affairs         601     9         2            0         2          0
#         ArgentinaCPI     80     2         0            0         0          0
#         BankWages       474     4         2            0         3          0
#         BenderlyZwick    31     5         0            0         0          0
#
#                        n_numeric  \
# Package Item
# AER     Affairs                7
#         ArgentinaCPI           2
#         BankWages              1
# ...

# %%
pd.read_csv(filename, skiprows= [1,3,5]).head(4)
# Out:
#   Package             Item                                              Title  \
# 0     AER     ArgentinaCPI                  Consumer Price Index in Argentina
# 1     AER    BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 2     AER  CartelStability                                    CartelStability
# 3     AER        CASchools                         California Test Score Data
#
#    Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 0    80     2         0            0         0          0          2
# 1    31     5         0            0         0          0          5
# 2   328     5         2            0         3          0          2
# 3   420    14         1            2         2          0         10
#
#                                                  CSV  \
# 0  https://vincentarelbundock.github.io/Rdatasets...
# 1  https://vincentarelbundock.github.io/Rdatasets...
# 2  https://vincentarelbundock.github.io/Rdatasets...
# ...

# %%
pd.isnull(draft1)
# Out:
#              a      b      c      d      e      f      g      h      i      j  \
# Package  False  False  False  False  False  False  False  False  False  False
# AER      False  False  False  False  False  False  False  False  False  False
# AER      False  False  False  False  False  False  False  False  False  False
# AER      False  False  False  False  False  False  False  False  False  False
# AER      False  False  False  False  False  False  False  False  False  False
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# vcd      False  False  False  False  False  False  False  False  False  False
# vcd      False  False  False  False  False  False  False  False  False  False
# vcd      False  False  False  False  False  False  False  False  False  False
# vcd      False  False  False  False  False  False  False  False  False  False
# vcd      False  False  False  False  False  False  False  False  False  False
#
#              k
# Package  False
# ...

# %%
# get data set from HTML

url ='http://www.basketball-reference.com/leagues/NBA_2015_totals.html'
bb = pd.read_html(url)
bb[0].head(5) # the tables in the html are stored in list format,
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
type(draft1['Package']) # read column from df
# Out:
# pandas.core.series.Series

# %%
draft1[['Package','Item']] # read more than 1 column
# Out:
#      Package           Item
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1473     vcd       UKSoccer
# 1474     vcd   VisualAcuity
# 1475     vcd        VonBort
# 1476     vcd     WeldonDice
# 1477     vcd     WomenQueue
#
# [1478 rows x 2 columns]

# %%
giturl = 'https://github.com/aroonaram/Datasets/blob/main/titanic.csv'

# %%
ds1 = pd.read_csv(giturl, sep = '\t')

# %%
ds1
# Out:
#                                          <!DOCTYPE html>
# 0      <html lang="en" data-color-mode="auto" data-li...
# 1                                                 <head>
# 2                                 <meta charset="utf-8">
# 3        <link rel="dns-prefetch" href="https://githu...
# 4        <link rel="dns-prefetch" href="https://avata...
# ...                                                  ...
# 14299                                  </clipboard-copy>
# 14300                                             </div>
# 14301                                        </template>
# 14302                                            </body>
# 14303                                            </html>
#
# [14304 rows x 1 columns]
